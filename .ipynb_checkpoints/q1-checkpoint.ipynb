# %%
import json
import pandas as pd

# Load JSON data (if reading from a file)
with open("q1.json", "r") as f:
    quiz_data = json.load(f)

# %%
quiz_info = {
    "quiz_id": quiz_data["quiz"]["id"],
    "title": quiz_data["quiz"]["title"],
    "topic": quiz_data["quiz"]["topic"],
    "questions_count": quiz_data["quiz"]["questions_count"],
    "duration": quiz_data["quiz"]["duration"],
    "negative_marks": quiz_data["quiz"]["negative_marks"],
    "correct_answer_marks": quiz_data["quiz"]["correct_answer_marks"],
}
quiz_df = pd.DataFrame([quiz_info])
quiz_df
# Out:
#    quiz_id                                              title  \
# 0       43  Structural Organisation in Animals and Plants (7)
#
#                                 topic  questions_count  duration  \
# 0  Structural Organisation in Animals              128       128
#
#   negative_marks correct_answer_marks
# 0            1.0                  4.0

# %%
df_main = pd.json_normalize(quiz_data)
df_main.head(2)
# Out:
#    quiz.id quiz.name                                         quiz.title  \
# 0       43      None  Structural Organisation in Animals and Plants (7)
#
#   quiz.description quiz.difficulty_level                          quiz.topic  \
# 0                                   None  Structural Organisation in Animals
#
#                        quiz.time  quiz.is_published  \
# 0  2024-07-03T00:00:00.000+05:30               True
#
#                  quiz.created_at                quiz.updated_at  ...  \
# 0  2024-07-03T11:00:08.958+05:30  2024-09-23T18:43:27.751+05:30  ...
#
#    quiz.exam_id quiz.show_unanswered quiz.ends_at quiz.lives  quiz.live_count  \
# 0          None                False   2025-01-18       None        Free Test
#
#    quiz.coin_count  quiz.questions_count   quiz.daily_date  \
# 0               -1                   128  January 17, 2025
#
#    quiz.max_mistake_count                                     quiz.questions
# 0                      15  [{'id': 1827, 'description': 'The tissue which...
#
# [1 rows x 32 columns]

# %%
df_quiz = pd.json_normalize(quiz_data["quiz"]).add_prefix("quiz_")
df_quiz.drop(columns=["quiz_questions"],inplace=True)
df_quiz.head(2)
# Out:
#    quiz_id quiz_name                                         quiz_title  \
# 0       43      None  Structural Organisation in Animals and Plants (7)
#
#   quiz_description quiz_difficulty_level                          quiz_topic  \
# 0                                   None  Structural Organisation in Animals
#
#                        quiz_time  quiz_is_published  \
# 0  2024-07-03T00:00:00.000+05:30               True
#
#                  quiz_created_at                quiz_updated_at  ...  \
# 0  2024-07-03T11:00:08.958+05:30  2024-09-23T18:43:27.751+05:30  ...
#
#    quiz_banner_id quiz_exam_id quiz_show_unanswered quiz_ends_at  quiz_lives  \
# 0            None         None                False   2025-01-18        None
#
#    quiz_live_count  quiz_coin_count  quiz_questions_count   quiz_daily_date  \
# 0        Free Test               -1                   128  January 17, 2025
#
#   quiz_max_mistake_count
# 0                     15
#
# [1 rows x 31 columns]

# %%
df_questions = pd.json_normalize(quiz_data["quiz"], record_path="questions", record_prefix="question_")
df_questions["quiz_id"] = quiz_data["quiz"]["id"]  # Add quiz_id manually for merging
df_questions = df_questions.merge(df_quiz, left_on="quiz_id", right_on="quiz_id", how="left")
df_questions.head(2)
# Out:
#    question_id                               question_description  \
# 0         1827  The tissue which has free surface that faces e...
# 1         1828  Epithelial tissue is distinguished from connec...
#
#   question_difficulty_level                       question_topic  \
# 0                      None  structural organisation in animals
# 1                      None  structural organisation in animals
#
#    question_is_published            question_created_at  \
# 0                   True  2024-07-02T12:43:34.360+05:30
# 1                   True  2024-07-02T12:50:56.100+05:30
#
#              question_updated_at  \
# 0  2024-11-30T18:39:20.587+05:30
# 1  2024-11-30T18:39:20.788+05:30
#
#                           question_detailed_solution question_type  \
# 0  **Explanation:**\n\nThe tissue that has a free...
# 1  **Epithelial Tissue**\n\n* Epithelial tissue i...
#
#    question_is_mandatory  ...  quiz_banner_id quiz_exam_id  \
# 0                  False  ...            None         None
# 1                  False  ...            None         None
#
#    quiz_show_unanswered  quiz_ends_at quiz_lives quiz_live_count  \
# 0                 False    2025-01-18       None       Free Test
# 1                 False    2025-01-18       None       Free Test
#
#   quiz_coin_count quiz_questions_count   quiz_daily_date  \
# 0              -1                  128  January 17, 2025
# 1              -1                  128  January 17, 2025
#
#   quiz_max_mistake_count
# 0                     15
# 1                     15
#
# [2 rows x 57 columns]

# %%
df_questions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 128 entries, 0 to 127
# Data columns (total 57 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   question_id                   128 non-null    int64
#  1   question_description          128 non-null    object
#  2   question_difficulty_level     0 non-null      object
#  3   question_topic                128 non-null    object
#  4   question_is_published         128 non-null    bool
#  5   question_created_at           128 non-null    object
#  6   question_updated_at           128 non-null    object
#  7   question_detailed_solution    119 non-null    object
#  8   question_type                 63 non-null     object
#  9   question_is_mandatory         128 non-null    bool
#  10  question_show_in_feed         128 non-null    bool
#  11  question_pyq_label            5 non-null      object
#  12  question_topic_id             128 non-null    int64
#  13  question_reading_material_id  128 non-null    int64
#  14  question_fixed_at             5 non-null      object
#  15  question_fix_summary          5 non-null      object
#  16  question_created_by           0 non-null      object
#  17  question_updated_by           5 non-null      object
#  18  question_quiz_level           0 non-null      object
#  19  question_question_from        128 non-null    object
#  20  question_language             0 non-null      object
#  21  question_photo_url            3 non-null      object
#  22  question_photo_solution_url   0 non-null      object
#  23  question_is_saved             128 non-null    bool
#  24  question_tag                  128 non-null    object
#  25  question_options              128 non-null    object
#  26  quiz_id                       128 non-null    int64
#  27  quiz_name                     0 non-null      object
#  28  quiz_title                    128 non-null    object
#  29  quiz_description              128 non-null    object
#  30  quiz_difficulty_level         0 non-null      object
#  31  quiz_topic                    128 non-null    object
#  32  quiz_time                     128 non-null    object
#  33  quiz_is_published             128 non-null    bool
#  34  quiz_created_at               128 non-null    object
#  35  quiz_updated_at               128 non-null    object
#  36  quiz_duration                 128 non-null    int64
#  37  quiz_end_time                 128 non-null    object
#  38  quiz_negative_marks           128 non-null    object
#  39  quiz_correct_answer_marks     128 non-null    object
#  40  quiz_shuffle                  128 non-null    bool
#  41  quiz_show_answers             128 non-null    bool
#  42  quiz_lock_solutions           128 non-null    bool
#  43  quiz_is_form                  128 non-null    bool
#  44  quiz_show_mastery_option      128 non-null    bool
#  45  quiz_quiz_type                0 non-null      object
#  46  quiz_is_custom                128 non-null    bool
#  47  quiz_banner_id                0 non-null      object
#  48  quiz_exam_id                  0 non-null      object
#  49  quiz_show_unanswered          128 non-null    bool
#  50  quiz_ends_at                  128 non-null    object
#  51  quiz_lives                    0 non-null      object
#  52  quiz_live_count               128 non-null    object
#  53  quiz_coin_count               128 non-null    int64
#  54  quiz_questions_count          128 non-null    int64
#  55  quiz_daily_date               128 non-null    object
#  56  quiz_max_mistake_count        128 non-null    int64
# dtypes: bool(12), int64(8), object(37)
# memory usage: 47.5+ KB

# %%
df_questions_exploded = df_questions.explode("question_options")
df_options = pd.json_normalize(df_questions_exploded["question_options"])
df_options = df_options.add_prefix('options_')
df_options = df_options.rename({'options_question_id':'question_id'}, axis='columns',errors='raise')
df_questions_exploded.drop(columns=["question_options"],inplace=True)
df_questions_exploded.head(2)
# Out:
#    question_id                               question_description  \
# 0         1827  The tissue which has free surface that faces e...
# 0         1827  The tissue which has free surface that faces e...
#
#   question_difficulty_level                       question_topic  \
# 0                      None  structural organisation in animals
# 0                      None  structural organisation in animals
#
#    question_is_published            question_created_at  \
# 0                   True  2024-07-02T12:43:34.360+05:30
# 0                   True  2024-07-02T12:43:34.360+05:30
#
#              question_updated_at  \
# 0  2024-11-30T18:39:20.587+05:30
# 0  2024-11-30T18:39:20.587+05:30
#
#                           question_detailed_solution question_type  \
# 0  **Explanation:**\n\nThe tissue that has a free...
# 0  **Explanation:**\n\nThe tissue that has a free...
#
#    question_is_mandatory  ...  quiz_banner_id quiz_exam_id  \
# 0                  False  ...            None         None
# 0                  False  ...            None         None
#
#    quiz_show_unanswered  quiz_ends_at quiz_lives quiz_live_count  \
# 0                 False    2025-01-18       None       Free Test
# 0                 False    2025-01-18       None       Free Test
#
#   quiz_coin_count quiz_questions_count   quiz_daily_date  \
# 0              -1                  128  January 17, 2025
# 0              -1                  128  January 17, 2025
#
#   quiz_max_mistake_count
# 0                     15
# 0                     15
#
# [2 rows x 56 columns]

# %%
df_complete = df_questions_exploded.merge(df_options, on="question_id", how="left")
df_complete = df_complete.drop_duplicates()

# %%
df_complete.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 512 entries, 0 to 2035
# Data columns (total 63 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   question_id                   512 non-null    int64
#  1   question_description          512 non-null    object
#  2   question_difficulty_level     0 non-null      object
#  3   question_topic                512 non-null    object
#  4   question_is_published         512 non-null    bool
#  5   question_created_at           512 non-null    object
#  6   question_updated_at           512 non-null    object
#  7   question_detailed_solution    476 non-null    object
#  8   question_type                 252 non-null    object
#  9   question_is_mandatory         512 non-null    bool
#  10  question_show_in_feed         512 non-null    bool
#  11  question_pyq_label            20 non-null     object
#  12  question_topic_id             512 non-null    int64
#  13  question_reading_material_id  512 non-null    int64
#  14  question_fixed_at             20 non-null     object
#  15  question_fix_summary          20 non-null     object
#  16  question_created_by           0 non-null      object
#  17  question_updated_by           20 non-null     object
#  18  question_quiz_level           0 non-null      object
#  19  question_question_from        512 non-null    object
#  20  question_language             0 non-null      object
#  21  question_photo_url            12 non-null     object
#  22  question_photo_solution_url   0 non-null      object
#  23  question_is_saved             512 non-null    bool
#  24  question_tag                  512 non-null    object
#  25  quiz_id                       512 non-null    int64
#  26  quiz_name                     0 non-null      object
#  27  quiz_title                    512 non-null    object
#  28  quiz_description              512 non-null    object
#  29  quiz_difficulty_level         0 non-null      object
#  30  quiz_topic                    512 non-null    object
#  31  quiz_time                     512 non-null    object
#  32  quiz_is_published             512 non-null    bool
#  33  quiz_created_at               512 non-null    object
#  34  quiz_updated_at               512 non-null    object
#  35  quiz_duration                 512 non-null    int64
#  36  quiz_end_time                 512 non-null    object
#  37  quiz_negative_marks           512 non-null    object
#  38  quiz_correct_answer_marks     512 non-null    object
#  39  quiz_shuffle                  512 non-null    bool
#  40  quiz_show_answers             512 non-null    bool
#  41  quiz_lock_solutions           512 non-null    bool
#  42  quiz_is_form                  512 non-null    bool
#  43  quiz_show_mastery_option      512 non-null    bool
#  44  quiz_quiz_type                0 non-null      object
#  45  quiz_is_custom                512 non-null    bool
#  46  quiz_banner_id                0 non-null      object
#  47  quiz_exam_id                  0 non-null      object
#  48  quiz_show_unanswered          512 non-null    bool
#  49  quiz_ends_at                  512 non-null    object
#  50  quiz_lives                    0 non-null      object
#  51  quiz_live_count               512 non-null    object
#  52  quiz_coin_count               512 non-null    int64
#  53  quiz_questions_count          512 non-null    int64
#  54  quiz_daily_date               512 non-null    object
#  55  quiz_max_mistake_count        512 non-null    int64
#  56  options_id                    512 non-null    int64
#  57  options_description           512 non-null    object
#  58  options_is_correct            512 non-null    bool
#  59  options_created_at            512 non-null    object
#  60  options_updated_at            512 non-null    object
#  61  options_unanswered            512 non-null    bool
#  62  options_photo_url             0 non-null      object
# dtypes: bool(14), int64(9), object(40)
# memory usage: 207.0+ KB

# %%
df_complete.head(5)
# Out:
#     question_id                               question_description  \
# 0          1827  The tissue which has free surface that faces e...
# 1          1827  The tissue which has free surface that faces e...
# 2          1827  The tissue which has free surface that faces e...
# 3          1827  The tissue which has free surface that faces e...
# 16         1828  Epithelial tissue is distinguished from connec...
#
#    question_difficulty_level                       question_topic  \
# 0                       None  structural organisation in animals
# 1                       None  structural organisation in animals
# 2                       None  structural organisation in animals
# 3                       None  structural organisation in animals
# 16                      None  structural organisation in animals
#
#     question_is_published            question_created_at  \
# 0                    True  2024-07-02T12:43:34.360+05:30
# 1                    True  2024-07-02T12:43:34.360+05:30
# 2                    True  2024-07-02T12:43:34.360+05:30
# 3                    True  2024-07-02T12:43:34.360+05:30
# 16                   True  2024-07-02T12:50:56.100+05:30
#
#               question_updated_at  \
# 0   2024-11-30T18:39:20.587+05:30
# 1   2024-11-30T18:39:20.587+05:30
# 2   2024-11-30T18:39:20.587+05:30
# 3   2024-11-30T18:39:20.587+05:30
# 16  2024-11-30T18:39:20.788+05:30
#
#                            question_detailed_solution question_type  \
# 0   **Explanation:**\n\nThe tissue that has a free...
# 1   **Explanation:**\n\nThe tissue that has a free...
# 2   **Explanation:**\n\nThe tissue that has a free...
# 3   **Explanation:**\n\nThe tissue that has a free...
# 16  **Epithelial Tissue**\n\n* Epithelial tissue i...
#
#     question_is_mandatory  ...  quiz_questions_count   quiz_daily_date  \
# 0                   False  ...                   128  January 17, 2025
# 1                   False  ...                   128  January 17, 2025
# 2                   False  ...                   128  January 17, 2025
# 3                   False  ...                   128  January 17, 2025
# 16                  False  ...                   128  January 17, 2025
#
#     quiz_max_mistake_count  options_id         options_description  \
# 0                       15        7321             Muscular tissue
# 1                       15        7322     Fluid connective tissue
# 2                       15        7323           Epithelial tissue
# 3                       15        7324              Nervous tissue
# 16                      15        7325  large extracellular matrix
#
#    options_is_correct             options_created_at  \
# 0               False  2024-07-02T12:43:34.365+05:30
# 1               False  2024-07-02T12:43:34.369+05:30
# 2                True  2024-07-02T12:43:34.372+05:30
# 3               False  2024-07-02T12:43:34.376+05:30
# 16              False  2024-07-02T12:50:56.110+05:30
#
#                options_updated_at options_unanswered options_photo_url
# 0   2024-07-02T12:43:34.365+05:30              False              None
# 1   2024-07-02T12:43:34.369+05:30              False              None
# 2   2024-07-02T12:43:34.372+05:30              False              None
# 3   2024-07-02T12:43:34.376+05:30              False              None
# 16  2024-07-02T12:50:56.110+05:30              False              None
#
# [5 rows x 63 columns]
